# %% [markdown]
# # Graphviz test and demonstration
#
# SPDX-License-Identifier: 0BSD

# %%
import graphviz

# %%
dir(graphviz)
# Out:
# ['CalledProcessError',
#  'DOT_BINARY',
#  'Digraph',
#  'DotSyntaxWarning',
#  'ENGINES',
#  'ExecutableNotFound',
#  'FORMATS',
#  'FORMATTERS',
#  'FileExistsError',
#  'FormatSuffixMismatchWarning',
#  'Graph',
#  'RENDERERS',
#  'RequiredArgumentError',
#  'SUPPORTED_JUPYTER_FORMATS',
#  'Source',
#  'UNFLATTEN_BINARY',
#  'UnknownSuffixWarning',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__copyright__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__version__',
#  '_compat',
#  '_defaults',
#  '_tools',
#  'backend',
#  'base',
#  'copying',
#  'dot',
#  'encoding',
#  'escape',
#  'exceptions',
#  'graphs',
#  'jupyter_integration',
#  'nohtml',
#  'parameters',
#  'pipe',
#  'pipe_lines',
#  'pipe_lines_string',
#  'pipe_string',
#  'piping',
#  'quoting',
#  'render',
#  'rendering',
#  'saving',
#  'set_default_engine',
#  'set_default_format',
# ...

# %%
g = graphviz.Digraph()

# %%
g.edge('X', 'Y')

# %%
g

# %%
g

# %%
g.edge('Y','Z')

# %%
g

# %%
g.edge('X', 'A')

# %%
g

# %% [markdown]
# ## Customizing `label` and `shape`
#
# Various drawings of [benzene](https://en.wikipedia.org/wiki/Benzene), to show how to specify custom Graphviz attributes (mainly `label` and `shape`).
#
# Also works on <code>graphviz.***Di***graph</code>.

# %%
g = graphviz.Graph()
g.engine = 'circo'  # Usually you'll want to leave the default of 'dot'.

for i in range(6):
    g.node(f'C{i}', label='C')
    g.node(f'H{i}', label='H')
    g.edge(f'C{i}', f'H{i}')

for i in range(6):
    for _ in range(1 + i % 2):
        g.edge(f'C{i}', f'C{(i + 1) % 6}')

g

# %%
g = graphviz.Graph()
g.engine = 'circo'  # Usually you'll want to leave the default of 'dot'.

for i in range(6):
    g.node(f'C{i}', label='C', shape='none')
    g.node(f'H{i}', label='H', shape='none')
    g.edge(f'C{i}', f'H{i}')

for i in range(6):
    for _ in range(1 + i % 2):
        g.edge(f'C{i}', f'C{(i + 1) % 6}')

g

# %%
g = graphviz.Graph()
g.engine = 'circo'  # Usually you'll want to leave the default of 'dot'.

for i in range(6):
    g.node(f'C{i}', shape='point')

for i in range(6):
    for _ in range(1 + i % 2):
        g.edge(f'C{i}', f'C{(i + 1) % 6}')

g

# %%
g = graphviz.Graph()
g.engine = 'circo'  # Usually you'll want to leave the default of 'dot'.

for i in range(6):
    g.node(f'C{i}', label='', shape='circle')
    g.node(f'H{i}', shape='point')
    g.edge(f'C{i}', f'H{i}')

for i in range(6):
    for _ in range(1 + i % 2):
        g.edge(f'C{i}', f'C{(i + 1) % 6}')

g

# %%
multiple_roots = graphviz.Digraph()
multiple_roots

# %%
multiple_roots.node('A')

# %%
multiple_roots

# %%
multiple_roots.node('B')

# %%
multiple_roots

# %%
multiple_roots.edge('A','B')

# %%
multiple_roots

# %%
multiple_roots.node('C')

# %%
multiple_roots

# %%
multiple_roots.node('p', shape='point')

# %%
multiple_roots

# %%
multiple_roots.edge('p','C')

# %%
multiple_roots

# %%
multiple_roots.edge('B','C')

# %%
multiple_roots

# %%
multiple_roots.node('q', shape='point')

# %%
multiple_roots

# %%
multiple_roots.edge('B', 'q')

# %%
multiple_roots

# %%
multiple_roots.edge('C','A')

# %%
multiple_roots

# %%
multiple_roots.edge('C','q')

# %%
multiple_roots

# %%
dir(graphviz.Digraph)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_a_list',
#  '_attr',
#  '_attr_list',
#  '_attr_plain',
#  '_comment',
#  '_copy_kwargs',
#  '_default_extension',
#  '_edge',
#  '_edge_plain',
#  '_encoding',
#  '_engine',
#  '_format',
#  '_formatter',
#  '_get_filepath',
#  '_get_format',
#  '_get_parameters',
#  '_get_pipe_parameters',
#  '_get_render_parameters',
#  '_getattr_from_dict',
#  '_head',
#  '_head_strict',
#  '_jupyter_mimetype',
#  '_mkdirs',
#  '_node',
#  '_pipe_future',
#  '_pipe_legacy',
#  '_pipe_lines',
#  '_pipe_lines_string',
# ...
