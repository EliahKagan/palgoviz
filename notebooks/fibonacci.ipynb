# %% [markdown]
# # Fibonacci call tree drawings
#
# SPDX-License-Identifier: 0BSD

# %%
from palgoviz.fibonacci import (
    draw_naive_call_tree_1,
    draw_naive_call_tree_2,
    draw_memoized_call_tree_1,
    draw_memoized_call_tree_2,
)

# %%
naive1 = draw_naive_call_tree_1(8)
naive1.result
# Out:
# 21

# %%
naive1.attr(size='15')
naive1

# %%
naive2 = draw_naive_call_tree_2(8)
naive2.result
# Out:
# 21

# %%
naive2.attr(size='15')
naive2

# %%
memoized1 = draw_memoized_call_tree_1(8)
memoized1.result
# Out:
# 21

# %%
memoized1.attr(size='3.5')
memoized1

# %%
memoized2 = draw_memoized_call_tree_2(8)
memoized2.result
# Out:
# 21

# %%
memoized2.attr(size='5')
memoized2
