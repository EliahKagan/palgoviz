# %%
import random

# %%
from palgoviz.search import (
    has_subset_sum_slow,
    has_subset_sum,
    has_subset_sum_alt,
    count_coin_change_slow,
    count_coin_change,
    count_coin_change_alt,
    find_av_winner,
)

# %%
has_subset_sum_slow([3, 7, -2, 1, -9], 2)
# Out:
# True

# %%
next(t for t in range(-20, 20) if not has_subset_sum_slow([14, 3, -9, -17, 2, -4, 7], t))
# Out:
# 18

# %%
has_subset_sum_slow([14, 3, -9, -17, 2, -4], 8)
# Out:
# True

# %%
prng = random.Random(7737161547226600500)
a = [prng.randrange(-1000, 1001) for _ in range(30)]
sum(a)  # Should always be the same, since we're seeding the same.
# Out:
# 249

# %%
sum(x for x in a if x > 0)
# Out:
# 9155

# %%
has_subset_sum_slow(a, 8000)
# Out:
# True

# %%
has_subset_sum(a, 8000)
# Out:
# True

# %%
has_subset_sum_alt(a, 8000)
# Out:
# True

# %%
b = a[::-1]

# %%
# has_subset_sum_slow(b, 8000)  # even slower

# %%
has_subset_sum(b, 8000)
# Out:
# True

# %%
has_subset_sum_alt(b, 8000)
# Out:
# True

# %%
count_coin_change_slow([1, 2, 5], 20)
# Out:
# 29

# %%
count_coin_change_slow([2, 3, 5, 7, 11, 13, 17, 19, 23], 200)
# Out:
# 1599464

# %%
count_coin_change([2, 3, 5, 7, 11, 13, 17, 19, 23], 200)
# Out:
# 1599464

# %%
count_coin_change_alt([2, 3, 5, 7, 11, 13, 17, 19, 23], 200)
# Out:
# 1599464

# %%
find_av_winner(1, 3, 0, 0, 0, 1, 0, 2)
# Out:
# 'B'

# %%
from palgoviz.search import count_n_queens_solutions

# %%
[count_n_queens_solutions(n) for n in range(13)]
# Out:
# [1, 1, 0, 0, 2, 10, 4, 40, 92, 352, 724, 2680, 14200]

# %%
from palgoviz.search import two_sum_fast, _IntTrie, _IntBiTrie

# %%
t = _IntTrie(10)

# %%
t[23] = 'A'
t[813] = 'B'
t[146] = 'C'
t[20046] = 'D'
t[0] = 'E'
t[13] = 'F'

# %%
t.draw()

# %%
a = (-79, -48, -96, -22, -11, -27, -34, 40, 37, 18, -38, -76, -6, -49,
     -74, -69, -16, 72, 9, -13, 4, -24, -95, -35, 71)

# %%
hist = _IntBiTrie(10)
two_sum_fast(a, 2, mapping_factory=lambda: hist)
# Out:
# (7, 10)

# %%
hist.draw()

# %%
hist = _IntBiTrie(2)
two_sum_fast(a, 2, mapping_factory=lambda: hist)
# Out:
# (7, 10)

# %%
hist.draw()

# %%
hist = _IntBiTrie(32)
two_sum_fast(range(-10_000, 10_001, 76), 1508, mapping_factory=lambda: hist)
# Out:
# (141, 142)

# %%
hist.draw()

# %%
from collections import Counter
import random

# %%
from palgoviz.search import solve_boggle, solve_boggle_alt, solve_boggle_alt2

# %%
board1 = ('racecar',
          'poaxdog',
          'Parisol')

words1 = ['racecar', 'six', 'parisol', 'Paris', 'six', 'doos', 'doosd']

# %%
solve_boggle(board1, words1)
# Out:
# Counter({'racecar': 4, 'doos': 1, 'Paris': 1, 'six': 1})

# %%
solve_boggle_alt(board1, words1)
# Out:
# Counter({'racecar': 4, 'doos': 1, 'Paris': 1, 'six': 1})

# %%
solve_boggle_alt2(board1, words1)
# Out:
# Counter({'racecar': 4, 'doos': 1, 'Paris': 1, 'six': 1})

# %%
board2 = ['🤣🐍🧐😾😶😵😎👻👽🦊🎷🐍',
          '🐍🍉🦆🐼🌴🎨🎮🧩🐍🐍🎻💩',
          '🧯🖤🦓🦓🦓🧐🧐🦢🐍🦚🤡🙀',
          '🤐👺😁😁🐶🦨🐍🐙🐙🐙👩🐙',
          '🎃💩🤯🍒😲😱🧣😿😱🐍🐍🦓',
          '🦝🦝🍒🍒💩🎱💔🥝🥨💩💪🤠',
          '😤😿😿👀🥶😭🥶😻🧶😃🦾🤯',
          '🧐💩🙀🙀🐸😇🙃🌊🌵🤡😻🥶']

words2 = ['🥨🦝', '🦝🍒🍒🍒🤯😁', '🐸🥶👀🍒💩🥶', '🐸🥶👀🍒💩🎱💔🥶', '🐙🐙🐍']

# %%
solve_boggle(board2, words2)
# Out:
# Counter({'🐙🐙🐍': 4, '🦝🍒🍒🍒🤯😁': 1, '🐸🥶👀🍒💩🎱💔🥶': 1})

# %%
solve_boggle_alt(board2, words2)
# Out:
# Counter({'🐙🐙🐍': 4, '🦝🍒🍒🍒🤯😁': 1, '🐸🥶👀🍒💩🎱💔🥶': 1})

# %%
solve_boggle_alt2(board2, words2)
# Out:
# Counter({'🐙🐙🐍': 4, '🦝🍒🍒🍒🤯😁': 1, '🐸🥶👀🍒💩🎱💔🥶': 1})

# %% [markdown]
# ***FIXME:** Find `words.txt` and either commit it or write code that downloads it.*

# %%
with open('data/words.txt', encoding='utf_8') as file:
    many_words_unshuffled = [line.strip() for line in file]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 with open('data/words.txt', encoding='utf_8') as file:
#       2     many_words_unshuffled = [line.strip() for line in file]
#
# File ~\miniforge3\envs\palgoviz\Lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/words.txt'

# %%
gen = random.Random(9512285658517762052)
many_words = many_words_unshuffled[:]
gen.shuffle(many_words)
cat = ''.join(many_words)
big_board = tuple(''.join(gen.choice(cat) for _ in range(110)) for _ in range(110))

# %%
matches = solve_boggle(big_board, many_words)

# %%
matches_alt = solve_boggle_alt(big_board, many_words)

# %%
matches_alt2 = solve_boggle_alt2(big_board, many_words)

# %%
matches == matches_alt

# %%
matches == matches_alt2

# %%
len(matches)

# %%
Counter(len(word) for word in matches)

# %%
{word: freq for word, freq in matches.items() if len(word) == 9}
