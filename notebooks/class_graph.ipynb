# %%
import collections.abc

# %%
from algoviz.class_graph import (
    preorder_ancestors,
    preorder_descendants,
    postorder_ancestors,
    postorder_descendants,
    bfs_ancestors,
    bfs_descendants,
    draw,
)

# %% [markdown]
# ## Tests using `collections.abc`

# %%
preorder_ancestors(collections.abc.MutableSequence, collections.abc.MutableMapping)
# Out:
# ([collections.abc.MutableSequence,
#   collections.abc.Sequence,
#   collections.abc.Reversible,
#   collections.abc.Iterable,
#   object,
#   collections.abc.Collection,
#   collections.abc.Sized,
#   collections.abc.Container,
#   collections.abc.MutableMapping,
#   collections.abc.Mapping],
#  [(collections.abc.Sequence, collections.abc.MutableSequence),
#   (collections.abc.Reversible, collections.abc.Sequence),
#   (collections.abc.Iterable, collections.abc.Reversible),
#   (object, collections.abc.Iterable),
#   (collections.abc.Collection, collections.abc.Sequence),
#   (collections.abc.Sized, collections.abc.Collection),
#   (object, collections.abc.Sized),
#   (collections.abc.Iterable, collections.abc.Collection),
#   (collections.abc.Container, collections.abc.Collection),
#   (object, collections.abc.Container),
#   (collections.abc.Mapping, collections.abc.MutableMapping),
#   (collections.abc.Collection, collections.abc.Mapping)])

# %%
draw(*_)

# %%
postorder_ancestors(collections.abc.MutableSequence, collections.abc.MutableMapping)
# Out:
# ([object,
#   collections.abc.Iterable,
#   collections.abc.Reversible,
#   collections.abc.Sized,
#   collections.abc.Container,
#   collections.abc.Collection,
#   collections.abc.Sequence,
#   collections.abc.MutableSequence,
#   collections.abc.Mapping,
#   collections.abc.MutableMapping],
#  [(object, collections.abc.Iterable),
#   (collections.abc.Iterable, collections.abc.Reversible),
#   (collections.abc.Reversible, collections.abc.Sequence),
#   (object, collections.abc.Sized),
#   (collections.abc.Sized, collections.abc.Collection),
#   (collections.abc.Iterable, collections.abc.Collection),
#   (object, collections.abc.Container),
#   (collections.abc.Container, collections.abc.Collection),
#   (collections.abc.Collection, collections.abc.Sequence),
#   (collections.abc.Sequence, collections.abc.MutableSequence),
#   (collections.abc.Collection, collections.abc.Mapping),
#   (collections.abc.Mapping, collections.abc.MutableMapping)])

# %%
draw(*_)

# %%
bfs_ancestors(collections.abc.MutableSequence, collections.abc.MutableMapping)
# Out:
# ([collections.abc.MutableSequence,
#   collections.abc.MutableMapping,
#   collections.abc.Sequence,
#   collections.abc.Mapping,
#   collections.abc.Reversible,
#   collections.abc.Collection,
#   collections.abc.Iterable,
#   collections.abc.Sized,
#   collections.abc.Container,
#   object],
#  [(collections.abc.Sequence, collections.abc.MutableSequence),
#   (collections.abc.Mapping, collections.abc.MutableMapping),
#   (collections.abc.Reversible, collections.abc.Sequence),
#   (collections.abc.Collection, collections.abc.Sequence),
#   (collections.abc.Collection, collections.abc.Mapping),
#   (collections.abc.Iterable, collections.abc.Reversible),
#   (collections.abc.Sized, collections.abc.Collection),
#   (collections.abc.Iterable, collections.abc.Collection),
#   (collections.abc.Container, collections.abc.Collection),
#   (object, collections.abc.Iterable),
#   (object, collections.abc.Sized),
#   (object, collections.abc.Container)])

# %%
draw(*_)

# %%
preorder_ancestors(collections.abc.MutableSequence, collections.abc.MutableMapping,
                   node_filter=lambda c: c is not collections.abc.Collection)
# Out:
# ([collections.abc.MutableSequence,
#   collections.abc.Sequence,
#   collections.abc.Reversible,
#   collections.abc.Iterable,
#   object,
#   collections.abc.MutableMapping,
#   collections.abc.Mapping],
#  [(collections.abc.Sequence, collections.abc.MutableSequence),
#   (collections.abc.Reversible, collections.abc.Sequence),
#   (collections.abc.Iterable, collections.abc.Reversible),
#   (object, collections.abc.Iterable),
#   (collections.abc.Mapping, collections.abc.MutableMapping)])

# %%
draw(*_)

# %%
postorder_ancestors(collections.abc.MutableSequence, collections.abc.MutableMapping,
                    node_filter=lambda c: c is not collections.abc.Collection)
# Out:
# ([object,
#   collections.abc.Iterable,
#   collections.abc.Reversible,
#   collections.abc.Sequence,
#   collections.abc.MutableSequence,
#   collections.abc.Mapping,
#   collections.abc.MutableMapping],
#  [(object, collections.abc.Iterable),
#   (collections.abc.Iterable, collections.abc.Reversible),
#   (collections.abc.Reversible, collections.abc.Sequence),
#   (collections.abc.Sequence, collections.abc.MutableSequence),
#   (collections.abc.Mapping, collections.abc.MutableMapping)])

# %%
draw(*_)

# %%
bfs_ancestors(collections.abc.MutableSequence, collections.abc.MutableMapping,
              node_filter=lambda c: c is not collections.abc.Collection)
# Out:
# ([collections.abc.MutableSequence,
#   collections.abc.MutableMapping,
#   collections.abc.Sequence,
#   collections.abc.Mapping,
#   collections.abc.Reversible,
#   collections.abc.Iterable,
#   object],
#  [(collections.abc.Sequence, collections.abc.MutableSequence),
#   (collections.abc.Mapping, collections.abc.MutableMapping),
#   (collections.abc.Reversible, collections.abc.Sequence),
#   (collections.abc.Iterable, collections.abc.Reversible),
#   (object, collections.abc.Iterable)])

# %%
draw(*_)

# %%
nodes, edges = preorder_descendants(
    collections.abc.Iterable,
    node_filter=lambda c: c.__module__ == 'collections.abc')

# %%
nodes
# Out:
# [collections.abc.Iterable,
#  collections.abc.Iterator,
#  collections.abc.Generator,
#  collections.abc.Reversible,
#  collections.abc.Sequence,
#  collections.abc.ByteString,
#  collections.abc.MutableSequence,
#  collections.abc.Collection,
#  collections.abc.Set,
#  collections.abc.MutableSet,
#  collections.abc.KeysView,
#  collections.abc.ItemsView,
#  collections.abc.Mapping,
#  collections.abc.MutableMapping,
#  collections.abc.ValuesView]

# %%
edges
# Out:
# [(collections.abc.Iterable, collections.abc.Iterator),
#  (collections.abc.Iterator, collections.abc.Generator),
#  (collections.abc.Iterable, collections.abc.Reversible),
#  (collections.abc.Reversible, collections.abc.Sequence),
#  (collections.abc.Sequence, collections.abc.ByteString),
#  (collections.abc.Sequence, collections.abc.MutableSequence),
#  (collections.abc.Iterable, collections.abc.Collection),
#  (collections.abc.Collection, collections.abc.Set),
#  (collections.abc.Set, collections.abc.MutableSet),
#  (collections.abc.Set, collections.abc.KeysView),
#  (collections.abc.Set, collections.abc.ItemsView),
#  (collections.abc.Collection, collections.abc.Mapping),
#  (collections.abc.Mapping, collections.abc.MutableMapping),
#  (collections.abc.Collection, collections.abc.ValuesView),
#  (collections.abc.Collection, collections.abc.Sequence)]

# %%
draw(nodes, edges)

# %%
nodes, edges = postorder_descendants(
    collections.abc.Iterable,
    node_filter=lambda c: c.__module__ == 'collections.abc')

# %%
nodes
# Out:
# [collections.abc.Generator,
#  collections.abc.Iterator,
#  collections.abc.ByteString,
#  collections.abc.MutableSequence,
#  collections.abc.Sequence,
#  collections.abc.Reversible,
#  collections.abc.MutableSet,
#  collections.abc.KeysView,
#  collections.abc.ItemsView,
#  collections.abc.Set,
#  collections.abc.MutableMapping,
#  collections.abc.Mapping,
#  collections.abc.ValuesView,
#  collections.abc.Collection,
#  collections.abc.Iterable]

# %%
edges
# Out:
# [(collections.abc.Iterator, collections.abc.Generator),
#  (collections.abc.Iterable, collections.abc.Iterator),
#  (collections.abc.Sequence, collections.abc.ByteString),
#  (collections.abc.Sequence, collections.abc.MutableSequence),
#  (collections.abc.Reversible, collections.abc.Sequence),
#  (collections.abc.Iterable, collections.abc.Reversible),
#  (collections.abc.Set, collections.abc.MutableSet),
#  (collections.abc.Set, collections.abc.KeysView),
#  (collections.abc.Set, collections.abc.ItemsView),
#  (collections.abc.Collection, collections.abc.Set),
#  (collections.abc.Mapping, collections.abc.MutableMapping),
#  (collections.abc.Collection, collections.abc.Mapping),
#  (collections.abc.Collection, collections.abc.ValuesView),
#  (collections.abc.Collection, collections.abc.Sequence),
#  (collections.abc.Iterable, collections.abc.Collection)]

# %%
draw(nodes, edges)

# %%
nodes, edges = bfs_descendants(
    collections.abc.Iterable,
    node_filter=lambda c: c.__module__ == 'collections.abc')

# %%
nodes
# Out:
# [collections.abc.Iterable,
#  collections.abc.Iterator,
#  collections.abc.Reversible,
#  collections.abc.Collection,
#  collections.abc.Generator,
#  collections.abc.Sequence,
#  collections.abc.Set,
#  collections.abc.Mapping,
#  collections.abc.ValuesView,
#  collections.abc.ByteString,
#  collections.abc.MutableSequence,
#  collections.abc.MutableSet,
#  collections.abc.KeysView,
#  collections.abc.ItemsView,
#  collections.abc.MutableMapping]

# %%
edges
# Out:
# [(collections.abc.Iterable, collections.abc.Iterator),
#  (collections.abc.Iterable, collections.abc.Reversible),
#  (collections.abc.Iterable, collections.abc.Collection),
#  (collections.abc.Iterator, collections.abc.Generator),
#  (collections.abc.Reversible, collections.abc.Sequence),
#  (collections.abc.Collection, collections.abc.Set),
#  (collections.abc.Collection, collections.abc.Mapping),
#  (collections.abc.Collection, collections.abc.ValuesView),
#  (collections.abc.Collection, collections.abc.Sequence),
#  (collections.abc.Sequence, collections.abc.ByteString),
#  (collections.abc.Sequence, collections.abc.MutableSequence),
#  (collections.abc.Set, collections.abc.MutableSet),
#  (collections.abc.Set, collections.abc.KeysView),
#  (collections.abc.Set, collections.abc.ItemsView),
#  (collections.abc.Mapping, collections.abc.MutableMapping)]

# %%
draw(nodes, edges)

# %% [markdown]
# ## Tests using `class_graph.examples.abc_stubs`

# %%
from algoviz.class_graph.examples import abc_stubs

# %%
preorder_ancestors(abc_stubs.MutableSequence, abc_stubs.MutableMapping)
# Out:
# ([algoviz.class_graph.examples.abc_stubs.MutableSequence,
#   algoviz.class_graph.examples.abc_stubs.Sequence,
#   algoviz.class_graph.examples.abc_stubs.Reversible,
#   algoviz.class_graph.examples.abc_stubs.Iterable,
#   object,
#   algoviz.class_graph.examples.abc_stubs.Collection,
#   algoviz.class_graph.examples.abc_stubs.Sized,
#   algoviz.class_graph.examples.abc_stubs.Container,
#   algoviz.class_graph.examples.abc_stubs.MutableMapping,
#   algoviz.class_graph.examples.abc_stubs.Mapping],
#  [(algoviz.class_graph.examples.abc_stubs.Sequence,
#    algoviz.class_graph.examples.abc_stubs.MutableSequence),
#   (algoviz.class_graph.examples.abc_stubs.Reversible,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Reversible),
#   (object, algoviz.class_graph.examples.abc_stubs.Iterable),
#   (algoviz.class_graph.examples.abc_stubs.Collection,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Sized,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (object, algoviz.class_graph.examples.abc_stubs.Sized),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (algoviz.class_graph.examples.abc_stubs.Container,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (object, algoviz.class_graph.examples.abc_stubs.Container),
#   (algoviz.class_graph.examples.abc_stubs.Mapping,
#    algoviz.class_graph.examples.abc_stubs.MutableMapping),
#   (algoviz.class_graph.examples.abc_stubs.Collection,
#    algoviz.class_graph.examples.abc_stubs.Mapping)])

# %%
draw(*_)

# %%
postorder_ancestors(abc_stubs.MutableSequence, abc_stubs.MutableMapping)
# Out:
# ([object,
#   algoviz.class_graph.examples.abc_stubs.Iterable,
#   algoviz.class_graph.examples.abc_stubs.Reversible,
#   algoviz.class_graph.examples.abc_stubs.Sized,
#   algoviz.class_graph.examples.abc_stubs.Container,
#   algoviz.class_graph.examples.abc_stubs.Collection,
#   algoviz.class_graph.examples.abc_stubs.Sequence,
#   algoviz.class_graph.examples.abc_stubs.MutableSequence,
#   algoviz.class_graph.examples.abc_stubs.Mapping,
#   algoviz.class_graph.examples.abc_stubs.MutableMapping],
#  [(object, algoviz.class_graph.examples.abc_stubs.Iterable),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Reversible),
#   (algoviz.class_graph.examples.abc_stubs.Reversible,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (object, algoviz.class_graph.examples.abc_stubs.Sized),
#   (algoviz.class_graph.examples.abc_stubs.Sized,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (object, algoviz.class_graph.examples.abc_stubs.Container),
#   (algoviz.class_graph.examples.abc_stubs.Container,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (algoviz.class_graph.examples.abc_stubs.Collection,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Sequence,
#    algoviz.class_graph.examples.abc_stubs.MutableSequence),
#   (algoviz.class_graph.examples.abc_stubs.Collection,
#    algoviz.class_graph.examples.abc_stubs.Mapping),
#   (algoviz.class_graph.examples.abc_stubs.Mapping,
#    algoviz.class_graph.examples.abc_stubs.MutableMapping)])

# %%
draw(*_)

# %%
bfs_ancestors(abc_stubs.MutableSequence, abc_stubs.MutableMapping)
# Out:
# ([algoviz.class_graph.examples.abc_stubs.MutableSequence,
#   algoviz.class_graph.examples.abc_stubs.MutableMapping,
#   algoviz.class_graph.examples.abc_stubs.Sequence,
#   algoviz.class_graph.examples.abc_stubs.Mapping,
#   algoviz.class_graph.examples.abc_stubs.Reversible,
#   algoviz.class_graph.examples.abc_stubs.Collection,
#   algoviz.class_graph.examples.abc_stubs.Iterable,
#   algoviz.class_graph.examples.abc_stubs.Sized,
#   algoviz.class_graph.examples.abc_stubs.Container,
#   object],
#  [(algoviz.class_graph.examples.abc_stubs.Sequence,
#    algoviz.class_graph.examples.abc_stubs.MutableSequence),
#   (algoviz.class_graph.examples.abc_stubs.Mapping,
#    algoviz.class_graph.examples.abc_stubs.MutableMapping),
#   (algoviz.class_graph.examples.abc_stubs.Reversible,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Collection,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Collection,
#    algoviz.class_graph.examples.abc_stubs.Mapping),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Reversible),
#   (algoviz.class_graph.examples.abc_stubs.Sized,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (algoviz.class_graph.examples.abc_stubs.Container,
#    algoviz.class_graph.examples.abc_stubs.Collection),
#   (object, algoviz.class_graph.examples.abc_stubs.Iterable),
#   (object, algoviz.class_graph.examples.abc_stubs.Sized),
#   (object, algoviz.class_graph.examples.abc_stubs.Container)])

# %%
draw(*_)

# %%
preorder_ancestors(abc_stubs.MutableSequence, abc_stubs.MutableMapping,
                   node_filter=lambda c: c is not abc_stubs.Collection)
# Out:
# ([algoviz.class_graph.examples.abc_stubs.MutableSequence,
#   algoviz.class_graph.examples.abc_stubs.Sequence,
#   algoviz.class_graph.examples.abc_stubs.Reversible,
#   algoviz.class_graph.examples.abc_stubs.Iterable,
#   object,
#   algoviz.class_graph.examples.abc_stubs.MutableMapping,
#   algoviz.class_graph.examples.abc_stubs.Mapping],
#  [(algoviz.class_graph.examples.abc_stubs.Sequence,
#    algoviz.class_graph.examples.abc_stubs.MutableSequence),
#   (algoviz.class_graph.examples.abc_stubs.Reversible,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Reversible),
#   (object, algoviz.class_graph.examples.abc_stubs.Iterable),
#   (algoviz.class_graph.examples.abc_stubs.Mapping,
#    algoviz.class_graph.examples.abc_stubs.MutableMapping)])

# %%
draw(*_)

# %%
postorder_ancestors(abc_stubs.MutableSequence, abc_stubs.MutableMapping,
                    node_filter=lambda c: c is not abc_stubs.Collection)
# Out:
# ([object,
#   algoviz.class_graph.examples.abc_stubs.Iterable,
#   algoviz.class_graph.examples.abc_stubs.Reversible,
#   algoviz.class_graph.examples.abc_stubs.Sequence,
#   algoviz.class_graph.examples.abc_stubs.MutableSequence,
#   algoviz.class_graph.examples.abc_stubs.Mapping,
#   algoviz.class_graph.examples.abc_stubs.MutableMapping],
#  [(object, algoviz.class_graph.examples.abc_stubs.Iterable),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Reversible),
#   (algoviz.class_graph.examples.abc_stubs.Reversible,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Sequence,
#    algoviz.class_graph.examples.abc_stubs.MutableSequence),
#   (algoviz.class_graph.examples.abc_stubs.Mapping,
#    algoviz.class_graph.examples.abc_stubs.MutableMapping)])

# %%
draw(*_)

# %%
bfs_ancestors(abc_stubs.MutableSequence, abc_stubs.MutableMapping,
              node_filter=lambda c: c is not abc_stubs.Collection)
# Out:
# ([algoviz.class_graph.examples.abc_stubs.MutableSequence,
#   algoviz.class_graph.examples.abc_stubs.MutableMapping,
#   algoviz.class_graph.examples.abc_stubs.Sequence,
#   algoviz.class_graph.examples.abc_stubs.Mapping,
#   algoviz.class_graph.examples.abc_stubs.Reversible,
#   algoviz.class_graph.examples.abc_stubs.Iterable,
#   object],
#  [(algoviz.class_graph.examples.abc_stubs.Sequence,
#    algoviz.class_graph.examples.abc_stubs.MutableSequence),
#   (algoviz.class_graph.examples.abc_stubs.Mapping,
#    algoviz.class_graph.examples.abc_stubs.MutableMapping),
#   (algoviz.class_graph.examples.abc_stubs.Reversible,
#    algoviz.class_graph.examples.abc_stubs.Sequence),
#   (algoviz.class_graph.examples.abc_stubs.Iterable,
#    algoviz.class_graph.examples.abc_stubs.Reversible),
#   (object, algoviz.class_graph.examples.abc_stubs.Iterable)])

# %%
draw(*_)

# %%
nodes, edges = preorder_descendants(
    abc_stubs.Iterable,
    node_filter=lambda c: c.__module__ == 'class_graph.examples.abc_stubs')

# %%
nodes
# Out:
# []

# %%
edges
# Out:
# []

# %%
draw(nodes, edges)

# %%
nodes, edges = postorder_descendants(
    abc_stubs.Iterable,
    node_filter=lambda c: c.__module__ == 'class_graph.examples.abc_stubs')

# %%
nodes
# Out:
# []

# %%
edges
# Out:
# []

# %%
draw(nodes, edges)

# %%
nodes, edges = bfs_descendants(
    abc_stubs.Iterable,
    node_filter=lambda c: c.__module__ == 'class_graph.examples.abc_stubs')

# %%
nodes
# Out:
# []

# %%
edges
# Out:
# []

# %%
draw(nodes, edges)

# %% [markdown]
# ## Tests using built-in exception types

# %%
def is_builtin_non_error(exception_type):
    return (exception_type.__module__ == 'builtins' and
            not exception_type.__name__.endswith(('Error', 'Warning')))

# %%
preorder_descendants(BaseException, node_filter=is_builtin_non_error)
# Out:
# ([BaseException,
#   BaseExceptionGroup,
#   ExceptionGroup,
#   Exception,
#   StopAsyncIteration,
#   StopIteration,
#   GeneratorExit,
#   KeyboardInterrupt,
#   SystemExit],
#  [(BaseException, BaseExceptionGroup),
#   (BaseExceptionGroup, ExceptionGroup),
#   (BaseException, Exception),
#   (Exception, StopAsyncIteration),
#   (Exception, StopIteration),
#   (Exception, ExceptionGroup),
#   (BaseException, GeneratorExit),
#   (BaseException, KeyboardInterrupt),
#   (BaseException, SystemExit)])

# %%
draw(*_)

# %%
postorder_descendants(BaseException, node_filter=is_builtin_non_error)
# Out:
# ([ExceptionGroup,
#   BaseExceptionGroup,
#   StopAsyncIteration,
#   StopIteration,
#   Exception,
#   GeneratorExit,
#   KeyboardInterrupt,
#   SystemExit,
#   BaseException],
#  [(BaseExceptionGroup, ExceptionGroup),
#   (BaseException, BaseExceptionGroup),
#   (Exception, StopAsyncIteration),
#   (Exception, StopIteration),
#   (Exception, ExceptionGroup),
#   (BaseException, Exception),
#   (BaseException, GeneratorExit),
#   (BaseException, KeyboardInterrupt),
#   (BaseException, SystemExit)])

# %%
draw(*_)

# %%
bfs_descendants(BaseException, node_filter=is_builtin_non_error)
# Out:
# ([BaseException,
#   BaseExceptionGroup,
#   Exception,
#   GeneratorExit,
#   KeyboardInterrupt,
#   SystemExit,
#   ExceptionGroup,
#   StopAsyncIteration,
#   StopIteration],
#  [(BaseException, BaseExceptionGroup),
#   (BaseException, Exception),
#   (BaseException, GeneratorExit),
#   (BaseException, KeyboardInterrupt),
#   (BaseException, SystemExit),
#   (BaseExceptionGroup, ExceptionGroup),
#   (Exception, StopAsyncIteration),
#   (Exception, StopIteration),
#   (Exception, ExceptionGroup)])

# %%
draw(*_)
