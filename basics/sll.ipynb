# %%
from sll import Node

# %%
p = Node(10, Node(20, Node(30)))
q = Node(10, Node(20, Node(30, Node(40))))
r = Node(50, Node(20, Node(30, Node(40))))
s = Node(10, Node(30, Node(40)))
t = Node(20, Node(30, Node(40)))
u = Node(10)
Node.draw()

# %%
del p, r
Node.draw()

# %%
v = Node(q, Node(10))
Node.draw()

# %%
del q, s, t
Node.draw()

# %%
v = v.next_node
Node.draw()

# %%
w = Node(30, Node(40))
Node.draw()

# %%
x = Node((lambda: Node(1, Node(2, Node(3, Node(4, Node(5)))))), Node(5))
Node.draw()

# %%
y = Node(0, x)
Node.draw()

# %%
x = x.value()
Node.draw()

# %%
del y
Node.draw()
