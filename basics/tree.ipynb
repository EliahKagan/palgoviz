# %%
from tree import FrozenNode, Node, draw, draw_iterative
from test_tree import _Maker

# %%
draw(_Maker(Node).tiny())

# %%
draw(_Maker(FrozenNode).tiny())

# %%
draw_iterative(_Maker(Node).tiny())

# %%
draw_iterative(_Maker(FrozenNode).tiny())

# %%
draw(_Maker(Node).medium())

# %%
draw(_Maker(FrozenNode).medium())

# %%
draw_iterative(_Maker(Node).medium())

# %%
draw_iterative(_Maker(FrozenNode).medium())

# %%
root = Node(1,
            Node(2,
                 Node(4,
                      Node(8, Node(16), Node(17)),
                      Node(9, None, Node(18))),
                 Node(5,
                      Node(10, Node(19), Node(20)),
                      Node(11, Node(21), None))),
            Node(3,
                 Node(6,
                      Node(12),
                      Node(13)),
                 Node(7,
                      Node(14, Node(1), Node(2)),
                      Node(15, None, Node(3)))))

g0 = draw(root)
g1 = draw(_Maker(Node).medium())
g2 = draw(_Maker(FrozenNode).medium())
str(g0) == str(g1) == str(g2)
# Out:
# True

# %%
draw(_Maker(Node).medium_redundant())

# %%
draw(_Maker(FrozenNode).medium_redundant())
